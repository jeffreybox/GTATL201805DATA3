# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

X, _ = make_blobs(n_samples=500, centers=6,
                            cluster_std=0.70, random_state=0)

# %%
# Plot and show scatter
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12)

# Fit the model to the data
kmeans.fit(X)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(X)

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[-1.41479237,  7.78375031],
#        [ 9.06561432, -2.88221508],
#        [ 0.27409792,  4.71918201],
#        [ 2.76256581,  0.98867762],
#        [ 6.21228264,  0.04853379],
#        [-2.02129214,  2.472801  ],
#        [ 1.46148943,  1.43899297],
#        [ 9.4847779 , -1.81672926],
#        [ 1.50200529,  4.30353512],
#        [ 5.58882333,  1.05152486],
#        [-0.81969122,  3.19692314],
#        [ 1.82812204,  0.25434457]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()

# %%
from sklearn.mixture import BayesianGaussianMixture as DPGMM
dpgmm = DPGMM(n_components=20)
dpgmm.fit(X)
predicted_clusters = dpgmm.predict(X)
centers = dpgmm.means_
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.show()
