# %%
# Dependencies
import requests
from pprint import pprint
#from config import api_key
import time

api_key = '82e9bbffc70245a98fb63120d7b9679b'

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "obama"

# Search for articles published between a begin and end date
begin_date = "20160101"
end_date = "20160130"

query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles
#articles_list = [article for article in articles["response"]["docs"]]

#for article in articles_list:
#    print(f'A snippet from the article: {article["snippet"]}')
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2018 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2016/01/08/opinion/president-barack-obama-guns-are-our-shared-responsibility.html',
#     'snippet': 'I will not campaign for, vote for or support any candidate, even in my own party, who does not support common-sense gun reform.',
#     'print_page': '23',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#       'height': 374,
#       'width': 600,
#       'legacy': {'xlargewidth': 600,
#        'xlarge': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-articleLarge.jpg',
#        'xlargeheight': 374},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbWide.jpg',
#        'widewidth': 190,
#        'wideheight': 126},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': 75,
#        'thumbnail': 'images/2016/01/07/opinion/00HawkinsWeb/00HawkinsWeb-thumbStandard.jpg',
#        'thumbnailwidth': 75},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Barack Obama: Guns Are Our Shared Responsibility',
#      'kicker': 'Op-Ed Contributor',
#      'content_kicker': 'Op-Ed Contributor',
#      'print_headline': 'Our Shared Responsibility',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Gun Control',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Executive Orders and Memorandums',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Firearms', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2016-01-08T00:03:35+0000',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'byline': {'original': 'By BARACK OBAMA',
#      'person': [{'firstname': 'Barack',
#        'middlename': None,
#        'lastname': 'OBAMA',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Op-Ed',
#     '_id': '568efce138f0d8580b9abac2',
#     'word_count': 858,
#     'score': 0.005281498,
#     'uri': 'nyt://article/a7894d4a-24ca-5a9e-abca-616317c8b656'},
#    {'web_url': 'https://www.nytimes.com/2016/01/08/universal/es/president-barack-obama-guns-are-our-shared-responsibility.html',
#     'snippet': 'Todos –gobierno, sector privado y los ciudadanos– debemos hacer un frente común para acabar con esta violencia sin sentido.',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#       'height': 412,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-articleLarge.jpg',
#        'xlargeheight': '412'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/08/opinion/08guns-copy-ES/08guns-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Barack Obama: Las armas de fuego son responsabilidad de todos',
#      'kicker': None,
#      'content_kicker': 'América ',
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Gun Control',
#       'rank': 1,
#       'major': None},
#      {'name': 'subject',
#       'value': 'Executive Orders and Memorandums',
#       'rank': 2,
#       'major': None},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 3,
#       'major': None}],
#     'pub_date': '2016-01-08T00:00:00Z',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'section_name': 'América',
#     'byline': {'original': 'Por BARACK OBAMA',
#      'person': [{'firstname': 'Por',
#        'middlename': 'Barack',
#        'lastname': 'OBAMA',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Op-Ed',
#     '_id': '568f12b038f0d8580b9abb00',
#     'word_count': 994,
#     'score': 0.0049603414},
#    {'web_url': 'https://www.nytimes.com/2016/01/25/opinion/campaign-stops/the-obama-theory-of-trump.html',
#     'snippet': 'In presidential elections, opposites attract.',
#     'print_page': '21',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#       'height': 393,
#       'width': 600,
#       'legacy': {'xlargewidth': 600,
#        'xlarge': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#        'xlargeheight': 393},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#        'widewidth': 190,
#        'wideheight': 126},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': 75,
#        'thumbnail': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#        'thumbnailwidth': 75},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'The Obama Theory of Trump',
#      'kicker': 'Op-Ed Contributor',
#      'content_kicker': 'Op-Ed Contributor',
#      'print_headline': 'The Obama Theory of Trump',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Presidential Election of 2016',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 2, 'major': 'N'},
#      {'name': 'persons', 'value': 'Obama, Barack', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Polls and Public Opinion',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Voting and Voters',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Republican Party',
#       'rank': 7,
#       'major': 'N'}],
#     'pub_date': '2016-01-25T08:21:17+0000',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'section_name': 'Campaign Stops',
#     'byline': {'original': 'By DAVID AXELROD',
#      'person': [{'firstname': 'David',
#        'middlename': None,
#        'lastname': 'AXELROD',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Op-Ed',
#     '_id': '56a5db0238f0d81529067d20',
#     'word_count': 1078,
#     'score': 0.00420678,
#     'uri': 'nyt://article/ae224f9a-e4c5-53b7-9681-905a15bbc393'},
#    {'web_url': 'https://www.nytimes.com/2016/01/11/opinion/the-obama-boom.html',
#     'snippet': 'Dire warnings from Republicans about the effect of President Obama’s policies on employment have simply not come true.',
#     'print_page': '23',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlargewidth': 600,
#        'xlarge': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-articleLarge.jpg',
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbWide.jpg',
#        'widewidth': 190,
#        'wideheight': 126},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': 75,
#        'thumbnail': 'images/2016/01/11/opinion/11krugmanWeb/11krugmanWeb-thumbStandard.jpg',
#        'thumbnailwidth': 75},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'The Obama Boom',
#      'kicker': 'Op-Ed Columnist',
#      'content_kicker': 'Op-Ed Columnist',
#      'print_headline': 'The  Obama  Boom',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Labor and Jobs', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2016-01-11T08:21:05+0000',
#     'document_type': 'article',
#     'news_desk': 'OpEd',
#     'byline': {'original': 'By PAUL KRUGMAN',
#      'person': [{'firstname': 'Paul',
#        'middlename': None,
#        'lastname': 'KRUGMAN',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Op-Ed',
#     '_id': '569365fc38f0d801cf86fb39',
#     'word_count': 803,
#     'score': 0.0015223442,
#     'uri': 'nyt://article/96cc9aff-1806-51ba-8dee-9fff728009f2'},
#    {'web_url': 'https://www.nytimes.com/video/us/100000004145097/obama-on-the-road.html',
#     'snippet': 'Highlights from President Obama’s remarks at a town-hall style meeting in Baton Rouge, La, on Thursday.',
#     'blog': {},
#     'source': 'AP',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbWide-v2.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#       'height': 337,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-articleLarge-v2.jpg',
#        'xlargeheight': '337'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/15/us/15obama1_hp/15obama1_hp-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Obama On the Road',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Obama, Barack',
#       'rank': 1,
#       'major': None}],
#     'pub_date': '2016-01-14T16:44:35Z',
#     'document_type': 'multimedia',
#     'news_desk': 'U.S.',
#     'byline': {'original': 'By THE ASSOCIATED PRESS',
#      'person': [],
#      'organization': 'THE ASSOCIATED PRESS'},
#     'type_of_material': 'Video',
#     '_id': '56981f5238f0d8108a7eb756',
#     'word_count': 16,
#     'score': 0.0014276291},
#    {'web_url': 'https://www.nytimes.com/politics/first-draft/2016/01/14/verbatim-barack-obama-on-michelle-obamas-presidential-ambitions/',
#     'snippet': '“Let me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.” — President Obama',
#     'abstract': '“Let me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.” — President Obama',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Verbatim: Barack Obama on Michelle Obama&#8217;s Presidential Ambitions',
#      'kicker': 'First Draft',
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Obama, Barack',
#       'rank': 1,
#       'major': None},
#      {'name': 'persons', 'value': 'Obama, Michelle', 'rank': 2, 'major': None},
#      {'name': 'glocations',
#       'value': 'Baton Rouge (La)',
#       'rank': 1,
#       'major': None}],
#     'pub_date': '2016-01-14T12:28:54Z',
#     'document_type': 'blogpost',
#     'news_desk': 'Politics',
#     'section_name': 'Politics',
#     'byline': {'original': 'By FIRST DRAFT',
#      'person': [{'firstname': 'First',
#        'middlename': None,
#        'lastname': 'DRAFT',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Blog',
#     '_id': '5697db3738f0d8108a7eb67d',
#     'word_count': 74,
#     'score': 0.0012641313},
#    {'web_url': 'https://www.nytimes.com/video/us/100000004157088/obama-on-flint-water-crisis.html',
#     'snippet': 'President Obama, speaking at the North American International Auto Show in Detroit, expressed sympathy and concern for residents of Flint, Mich., where there has been lead contamination in the drinking water.',
#     'blog': {},
#     'source': 'Reuters',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/21/us/21obama-vid/21obama-vid-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/21/us/21obama-vid/21obama-vid-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/21/us/21obama-vid/21obama-vid-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/21/us/21obama-vid/21obama-vid-articleLarge.jpg',
#        'xlargeheight': '400'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/21/us/21obama-vid/21obama-vid-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/21/us/21obama-vid/21obama-vid-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Obama on Flint Water Crisis',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Obama, Barack',
#       'rank': 1,
#       'major': None},
#      {'name': 'glocations', 'value': 'Flint (Mich)', 'rank': 2, 'major': None},
#      {'name': 'subject', 'value': 'Water Pollution', 'rank': 3, 'major': None},
#      {'name': 'subject', 'value': 'Lead', 'rank': 4, 'major': None}],
#     'pub_date': '2016-01-20T17:26:27Z',
#     'document_type': 'multimedia',
#     'news_desk': 'U.S.',
#     'byline': {'original': 'By REUTERS',
#      'person': [],
#      'organization': 'REUTERS'},
#     'type_of_material': 'Video',
#     '_id': '56a009a338f0d80627b20b46',
#     'word_count': 31,
#     'score': 0.0012432088},
#    {'web_url': 'https://www.nytimes.com/video/world/americas/100000004150287/obama-celebrates-deal-with-iran.html',
#     'snippet': 'President Obama expressed relief and happiness that several Americans who had been detained in Iran were returning home after the completion of a nuclear agreement with Tehran.',
#     'blog': {},
#     'source': 'Reuters',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-articleLarge.jpg',
#        'xlargeheight': '400'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/18/world/18-iran-hp-2/18-iran-hp-2-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Obama Celebrates Deal With Iran',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 1,
#       'major': None},
#      {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': None},
#      {'name': 'glocations', 'value': 'Iran', 'rank': 3, 'major': None},
#      {'name': 'subject',
#       'value': 'Prisons and Prisoners',
#       'rank': 4,
#       'major': None}],
#     'pub_date': '2016-01-17T12:19:29Z',
#     'document_type': 'multimedia',
#     'news_desk': 'World / Americas',
#     'section_name': 'Americas',
#     'byline': {'original': 'By THE ASSOCIATED PRESS',
#      'person': [],
#      'organization': 'THE ASSOCIATED PRESS'},
#     'type_of_material': 'Video',
#     '_id': '569bcd3538f0d821e003cd00',
#     'word_count': 27,
#     'score': 0.0012269607},
#    {'web_url': 'https://www.nytimes.com/video/us/politics/100000004141206/obama-on-terrorism.html',
#     'snippet': 'The president delivered his final State of the Union address on Tuesday and discussed the threat posed by the Islamic State.',
#     'blog': {},
#     'source': 'AP',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-articleLarge.jpg',
#        'xlargeheight': '400'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/13/us/sotu-blog-20/sotu-blog-20-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Obama on Terrorism',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'State of the Union Message (US)',
#       'rank': 1,
#       'major': None},
#      {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': None},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 3, 'major': None}],
#     'pub_date': '2016-01-12T22:09:23Z',
#     'document_type': 'multimedia',
#     'news_desk': 'U.S. / Politics',
#     'section_name': 'Politics',
#     'byline': {'original': 'By THE ASSOCIATED PRESS',
#      'person': [],
#      'organization': 'THE ASSOCIATED PRESS'},
#     'type_of_material': 'Video',
#     '_id': '5695bff338f0d83e7cfe0459',
#     'word_count': 21,
#     'score': 0.0012003526},
#    {'web_url': 'https://www.nytimes.com/video/us/politics/100000004141131/obama-on-economy.html',
#     'snippet': 'The president delivered his final State of the Union address on Tuesday and discussed economic growth.',
#     'blog': {},
#     'source': 'AP',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'wide': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subType': 'wide',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlargewidth': '600',
#        'xlarge': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-articleLarge.jpg',
#        'xlargeheight': '400'},
#       'subType': 'xlarge',
#       'crop_name': None},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnailheight': '75',
#        'thumbnail': 'images/2016/01/13/us/sotu-blog-9/sotu-blog-9-thumbStandard.jpg',
#        'thumbnailwidth': '75'},
#       'subType': 'thumbnail',
#       'crop_name': None}],
#     'headline': {'main': 'Obama on Economy',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Obama, Barack',
#       'rank': 1,
#       'major': None},
#      {'name': 'subject',
#       'value': 'State of the Union Message (US)',
#       'rank': 2,
#       'major': None},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 3,
#       'major': None}],
#     'pub_date': '2016-01-12T21:30:00Z',
#     'document_type': 'multimedia',
#     'news_desk': 'U.S. / Politics',
#     'section_name': 'Politics',
#     'byline': {'original': 'By THE ASSOCIATED PRESS',
#      'person': [],
#      'organization': 'THE ASSOCIATED PRESS'},
#     'type_of_material': 'Video',
#     '_id': '5695b6b738f0d83e7cfe0440',
#     'word_count': 16,
#     'score': 0.0012000195}],
#   'meta': {'hits': 748, 'offset': 0, 'time': 12}}}

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
